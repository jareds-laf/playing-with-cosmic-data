# %%
import blimpy
import numpy as np
# %matplotlib inline
import pylab as plt
from blimpy import Waterfall

# %%
AC0_GPU2 = Waterfall('Band_Test_BD_C512-beam0001.fil',max_load=8)

# %%
AC0_GPU2.info()
# Out:
# --- File Info ---
#       machine_id :                                0
#     telescope_id :                               -1
#          src_raj :                 4:09:22.00873993
#          src_dej :                12:17:39.84749624
#         az_start :             6.9287069824102e-310
#         za_start :             4.6633787335631e-310
#        data_type :                                1
#             fch1 :           3532.4999961853027 MHz
#             foff :           -7.62939453125e-06 MHz
#           nchans :                          4194304
#           nbeams :                                2
#            ibeam :                                1
#            nbits :                               32
#    tstart (ISOT) :          2023-05-10T22:08:42.502
#     tstart (MJD) :               60074.922714145854
#            tsamp :                         0.131072
#             nifs :                                1
#      barycentric :                                1
# ...

# %%
plt.figure(figsize=(10,6))
#AC0_GPU2.plot_waterfall(plt.figure(figsize=(10,6))
AC0_GPU2.plot_waterfall(f_start=3509,f_stop=3512)
#plt.axvline(x = 6667.883, color = 'w', label = 'axvline - full height')
plt.xlabel("Frequency (MHz)", fontsize=16)
plt.ylabel("Time (s)", fontsize=16)
#plt.colorbar(label="Power")
#plt.axvline(x = 6667.883, color = 'w', label = 'axvline - full height')
plt.xlabel("Frequency (MHz)", fontsize=16)
plt.ylabel("Time (s)", fontsize=16)
#plt.colorbar(label="Power")
# Out:
# Text(0, 0.5, 'Time (s)')

# %%
plt.figure(figsize=(10,6))
AC0_GPU2.plot_spectrum(t=0,f_start=3524,f_stop=3532)
plt.xlabel("Frequency (MHz)", fontsize=16)
plt.ylabel("Power(Counts)", fontsize=16)
# Out:
# extracting integration 0...
# Text(0, 0.5, 'Power(Counts)')
